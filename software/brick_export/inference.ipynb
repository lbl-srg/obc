# %% [markdown]
# ## Use cases:
# 1. Generating control sequences for real BAS controllers using CDL
# 2. FDD and other open loop verification
#   * only need input and output points
#   * only CDL sequences suffice
#   * add annotation tags to CDL blocks (elementary CDL block and composite block) --- higher priority
#   * May not need to parse the entire modelica elements. Stop at blocks?
#   * User specificies which blocks to parse (user input)
#   * Output:
#     * semantic model with inputs and output
#     * eventually these will need to be tied to BACnet points.
#   * Questions:
#     * how to verify user inputed blocks?
#     * What if there is user defined composite block using a bunch of CDL blocks (from `Buildings.Controls.CDL` or `Buildings.Controls.OBC.*` ) ?
#     * who does the BACnet point mapping?
#     * what about the sequences themselves? Are we storing it somehow?
#     * What about documentation?
#     * How to specify that some points will be need to undergo transformation before mapping to CDL input/output
#     * Do we allow annotations to propogate to lower blocks? Current CDL has a mechanism to propogate annotations.
# 3. Developing portable analytics applications
# 4. Developing portable advanced control sequences
#   * Each algorithm would have a BRICK or SPARQL query.
#   * Need Energy model and CDL sequences
#   * Output:
#     * semantic model with equipment and points (inputs and outputs)
#   * Questions:
#     * When should we stop parsing? Currently, I stop as soon as the element type does not start with `Buildings.*`
# 5. BOPTEST/simulation/Hardware in the loop
#   * needs energy model
#   * might need external references to BACnet points or other real world variables
#   * Output:
#     * semantic model with equipment and points (inputs and outputs)

# %%
import brickschema
from brickschema.namespaces import BRICK, RDFS, RDF
import json
from element_relationship import Element_Relationship_Extractor

# %%
modelica_brick_sensor_type_map = {
    'TemperatureTwoPort': BRICK['Temperature_Sensor'],
    'Temperature': BRICK['Temperature_Sensor'],
    'RelativeTemperature': BRICK['Temperature_Sensor'],
    'TemperatureWetBulbTwoPort': BRICK['Temperature_Sensor'],
    'VolumeFlowRate': BRICK['Flow_Sensor'],
    'RelativeHumidity': BRICK['Humditiy_Sensor'],
    'RelativeHumidityTwoPort': BRICK['Humditiy_Sensor'],
    'Pressure': BRICK['Pressure_Sensor'],
    'RelativePressure': BRICK['Pressure_Sensor']
}

modelica_brick_heat_exchanger_type_map = {
    'DryCoilCounterFlow': BRICK['Heating_Coil'],
    'DryCoilDiscretized': BRICK['Heating_Coil'],
    'DryCoilEffectivenessNTU': BRICK['Heating_Coil'], #DryCoil could also be for cooling in some climate zones, could be part of a heat exchanger,
    'WetCoilCounterFlow': BRICK['Cooling_Coil'],
    'WetCoilDiscretized': BRICK['Cooling_Coil'],
    'EvaporatorCondenser': BRICK['Heat_Exchanger'], #look at which side of compressor it is on to decide if it is evaporator or condensor
    'Heater_T': BRICK['Space_Heater'],
}

modelica_brick_actuator_type_map = {
    'Dampers.Exponential': BRICK['Damper'],
    'Dampers.MixingBox': BRICK['Damper'],
    'Dampers.MixingBoxMinimumFlow': BRICK['Damper'],
    'Dampers.PressureIndependent': BRICK['Damper'],
    'Valves.ThreeWayEqualPercentageLinear': BRICK['Valve'], #need more clarity on the brick side for valves
    'Valves.ThreeWayLinear': BRICK['Valve'],
    'Valves.ThreeWayTable': BRICK['Valve'],
    'Valves.TwoWayEqualPercentageLinear': BRICK['Valve'],
    'Valves.TwoWayLinear': BRICK['Valve'],
    'Valves.TwoWayPolynomial': BRICK['Valve'],
    'Valves.TwoWayPressureIndependent': BRICK['Valve'],
    'Valves.TwoWayQuickOpening': BRICK['Valve'],
    'Valves.TwoWayTable': BRICK['Valve']
}

modelica_brick_mover_type_map = { # anything can be pump or fan according to the media
    'FlowControlled_dp': BRICK['Pump'],
    'FlowControlled_m_flow': BRICK['Pump'],
    'SpeedControlled_Nrpm': BRICK['Fan'],
    'SpeedControlled_y': BRICK['Fan']
}

modelica_brick_thermal_zone_type_map = {
    'Detailed.MixedAir': BRICK['HVAC_Zone'],
    'ReducedOrder.EquivalentAirTemperature': BRICK['HVAC_Zone'],
    'ReducedOrder.RC': BRICK['HVAC_Zone'],
    'ReducedOrer.SolarGain': BRICK['HVAC_Zone']
}

modelica_brick_medium_type_map = {
    'Air': BRICK['Air'],
    'Water': BRICK['Water']
}

# %%
with open("config_boptest.json") as fp:
    config = json.load(fp)
config
# Out:
# {'model': 'Buildings.Examples.MultiZoneOfficeSimpleAir.TestCases.TestCase',
#  'generate_json': True}

# %%
element_extractor = Element_Relationship_Extractor(config_file = "config_boptest.json");

# %%
elements, relationships = element_extractor.extract_class_definition()
# Out:
# did not find og_type_specifier=Results type_specifier=Results model=Buildings.Examples.MultiZoneOfficeSimpleAir.BaseClasses.PartialHVAC parent=hvac.
# did not find og_type_specifier=BoundaryConditions.WeatherData.Bus type_specifier=BoundaryConditions.WeatherData.Bus model=Buildings.Examples.VAVReheat.BaseClasses.PartialFloor parent=flo.
# did not find og_type_specifier=BoundaryConditions.WeatherData.Bus type_specifier=BoundaryConditions.WeatherData.Bus model=Buildings.Examples.VAVReheat.BaseClasses.RoomLeakage parent=flo.leaSou.
# did not find og_type_specifier=BoundaryConditions.WeatherData.Bus type_specifier=BoundaryConditions.WeatherData.Bus model=Buildings.Examples.VAVReheat.BaseClasses.RoomLeakage parent=flo.leaEas.
# did not find og_type_specifier=BoundaryConditions.WeatherData.Bus type_specifier=BoundaryConditions.WeatherData.Bus model=Buildings.Examples.VAVReheat.BaseClasses.RoomLeakage parent=flo.leaNor.
# did not find og_type_specifier=BoundaryConditions.WeatherData.Bus type_specifier=BoundaryConditions.WeatherData.Bus model=Buildings.Examples.VAVReheat.BaseClasses.RoomLeakage parent=flo.leaWes.
# redeclaration element: hvac of type Buildings.Examples.MultiZoneOfficeSimpleAir.BaseClasses.ASHRAE2006
# did not find og_type_specifier=Results type_specifier=Results model=Buildings.Examples.MultiZoneOfficeSimpleAir.BaseClasses.PartialHVAC parent=hvac.
# did not find og_type_specifier=BaseClasses.Controls.ControlBus type_specifier=BaseClasses.Controls.ControlBus model=Buildings.Examples.VAVReheat.BaseClasses.Controls.PreCoolingStarter parent=hvac.modeSelector.preCooSta.
# did not find og_type_specifier=BaseClasses.Controls.ControlBus type_specifier=BaseClasses.Controls.ControlBus model=Buildings.Examples.VAVReheat.BaseClasses.Controls.RoomTemperatureSetpoint parent=hvac.TSetRoo.
# redeclaration element: flo of type Buildings.Examples.VAVReheat.Validation.BaseClasses.Floor
# did not find og_type_specifier=BoundaryConditions.WeatherData.Bus type_specifier=BoundaryConditions.WeatherData.Bus model=Buildings.Examples.VAVReheat.BaseClasses.PartialFloor parent=flo.
# did not find og_type_specifier=BoundaryConditions.WeatherData.Bus type_specifier=BoundaryConditions.WeatherData.Bus model=Buildings.Examples.VAVReheat.BaseClasses.RoomLeakage parent=flo.leaSou.
# did not find og_type_specifier=BoundaryConditions.WeatherData.Bus type_specifier=BoundaryConditions.WeatherData.Bus model=Buildings.Examples.VAVReheat.BaseClasses.RoomLeakage parent=flo.leaEas.
# did not find og_type_specifier=BoundaryConditions.WeatherData.Bus type_specifier=BoundaryConditions.WeatherData.Bus model=Buildings.Examples.VAVReheat.BaseClasses.RoomLeakage parent=flo.leaNor.
# did not find og_type_specifier=BoundaryConditions.WeatherData.Bus type_specifier=BoundaryConditions.WeatherData.Bus model=Buildings.Examples.VAVReheat.BaseClasses.RoomLeakage parent=flo.leaWes.

# %%
def get_brick_type(semantic_info):
    if semantic_info != "":
        return BRICK[semantic_info.split(" ")[-1].split(":")[1]]
    return ""

# %%
brick_graph = brickschema.Graph(load_brick=True)
all_points = list(brick_graph.transitive_subjects(object=BRICK['Point'], predicate=RDFS['subClassOf']))
all_zones = list(brick_graph.transitive_subjects(object=BRICK['Zone'], predicate=RDFS['subClassOf']))
all_equipment = list(brick_graph.transitive_subjects(object=BRICK['Equipment'], predicate=RDFS['subClassOf']))
all_systems = list(brick_graph.transitive_subjects(object=BRICK['System'], predicate=RDFS['subClassOf']))

for item in elements:
    type_specifier = elements[item]['type_specifier']
    semantic = elements[item].get('semantic', '')
    parent_semantic = ""
    if '.' in item:
        parent  = item.rsplit(".", 1)[0]
        parent_semantic = get_brick_type(elements[parent].get("semantic"))

    if semantic != "":
        brick_type = get_brick_type(semantic)
        print(item, 'a', brick_type)
        if brick_type in all_points:
            if parent_semantic in all_equipment or parent_semantic in all_zones or parent_semantic in all_systems:
                print(parent, BRICK['hasPoint'], item)
        if brick_type in all_zones:
            if parent_semantic in all_zones:
                print(parent, BRICK['hasPart'], item)
        if brick_type in all_equipment:
            if parent_semantic in all_equipment or parent_semantic in all_systems:
                print(parent, BRICK['hasPart'], item)
            if parent_semantic in all_zones:
                print(parent, BRICK['hasLocation'], item)
            
        if item in relationships:
            from_item_og = item
            from_item = item
        else:
            for fro in relationships:
                if "." in fro and fro.rsplit(".", 1)[0] == item:
                    from_item_og = fro
                    from_item = fro.rsplit(".", 1)[0]
                    break
        
        for to_item_og in relationships[from_item_og]:
            to_semantic = ""
            to_item = None
            if to_item_og in elements:
                to_item = to_item_og
            elif to_item_og.rsplit(".", 1)[0] in elements:
                to_item = to_item_og.rsplit(".", 1)[0]
            to_semantic = elements[to_item].get('semantic')
            
            if to_semantic != "":
                to_brick_type = get_brick_type(to_semantic)
                if brick_type in all_equipment:
                    if to_brick_type in all_equipment:
                        if from_item_og != from_item and to_item_og != to_item:
                            from_port = from_item_og.rsplit(".", 1)[1]
                            to_port = to_item_og.rsplit(".", 1)[1]
                            
                            if (from_port.startswith("port_b") or from_port.startswith("port2") or from_port.startswith("portb") or from_port.startswith("port_2")) and \
                                (to_port.startswith("port_a") or to_port.startswith("port1") or to_port.startswith("porta") or to_port.startswith("port_1")):
                                print(from_item, BRICK['feeds'], to_item)
                    if to_brick_type in all_points:
                        print(from_item, BRICK['hasPoint'], to_item)
# Out:
# chi a https://brickschema.org/schema/Brick#Chiller
# hvac.heaCoi a https://brickschema.org/schema/Brick#Heating_Coil
# hvac https://brickschema.org/schema/Brick#hasPart hvac.heaCoi
# hvac.heaCoi https://brickschema.org/schema/Brick#feeds hvac.cooCoi
# hvac.cooCoi a https://brickschema.org/schema/Brick#Cooling_Coil
# hvac https://brickschema.org/schema/Brick#hasPart hvac.cooCoi
# hvac.cooCoi https://brickschema.org/schema/Brick#feeds hvac.fanSup
# hvac.fanSup a https://brickschema.org/schema/Brick#Supply_Fan
# hvac https://brickschema.org/schema/Brick#hasPart hvac.fanSup
# hvac.fanSup https://brickschema.org/schema/Brick#hasPoint hvac.dpDisSupFan
# hvac.dpDisSupFan a https://brickschema.org/schema/Brick#Discharge_Air_Static_Pressure_Sensor
# hvac https://brickschema.org/schema/Brick#hasPoint hvac.dpDisSupFan
# hvac.VOut1 a https://brickschema.org/schema/Brick#Outside_Air_Flow_Sensor
# hvac https://brickschema.org/schema/Brick#hasPoint hvac.VOut1
# hvac.cor a https://brickschema.org/schema/Brick#VAV
# hvac https://brickschema.org/schema/Brick#hasPart hvac.cor
# hvac.cor.vav a https://brickschema.org/schema/Brick#Damper
# hvac.cor https://brickschema.org/schema/Brick#hasPart hvac.cor.vav
# hvac.cor.terHea a https://brickschema.org/schema/Brick#Heating_Coil
# hvac.cor https://brickschema.org/schema/Brick#hasPart hvac.cor.terHea
# hvac.cor.senTem a https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor
# hvac.cor https://brickschema.org/schema/Brick#hasPoint hvac.cor.senTem
# hvac.cor.senVolFlo a https://brickschema.org/schema/Brick#Supply_Air_Flow_Sensor
# hvac.cor https://brickschema.org/schema/Brick#hasPoint hvac.cor.senVolFlo
# hvac.cor.val a https://brickschema.org/schema/Brick#Heating_Valve
# hvac.cor https://brickschema.org/schema/Brick#hasPart hvac.cor.val
# hvac.cor.val https://brickschema.org/schema/Brick#feeds hvac.cor.terHea
# hvac.cor.yHea a https://brickschema.org/schema/Brick#Valve_Command
# hvac.cor https://brickschema.org/schema/Brick#hasPoint hvac.cor.yHea
# hvac.sou a https://brickschema.org/schema/Brick#VAV
# hvac https://brickschema.org/schema/Brick#hasPart hvac.sou
# hvac.sou.vav a https://brickschema.org/schema/Brick#Damper
# hvac.sou https://brickschema.org/schema/Brick#hasPart hvac.sou.vav
# hvac.sou.terHea a https://brickschema.org/schema/Brick#Heating_Coil
# hvac.sou https://brickschema.org/schema/Brick#hasPart hvac.sou.terHea
# hvac.sou.senTem a https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor
# hvac.sou https://brickschema.org/schema/Brick#hasPoint hvac.sou.senTem
# hvac.sou.senVolFlo a https://brickschema.org/schema/Brick#Supply_Air_Flow_Sensor
# hvac.sou https://brickschema.org/schema/Brick#hasPoint hvac.sou.senVolFlo
# hvac.sou.val a https://brickschema.org/schema/Brick#Heating_Valve
# hvac.sou https://brickschema.org/schema/Brick#hasPart hvac.sou.val
# hvac.sou.val https://brickschema.org/schema/Brick#feeds hvac.sou.terHea
# hvac.sou.yHea a https://brickschema.org/schema/Brick#Valve_Command
# hvac.sou https://brickschema.org/schema/Brick#hasPoint hvac.sou.yHea
# hvac.eas a https://brickschema.org/schema/Brick#VAV
# hvac https://brickschema.org/schema/Brick#hasPart hvac.eas
# hvac.eas.vav a https://brickschema.org/schema/Brick#Damper
# hvac.eas https://brickschema.org/schema/Brick#hasPart hvac.eas.vav
# hvac.eas.terHea a https://brickschema.org/schema/Brick#Heating_Coil
# hvac.eas https://brickschema.org/schema/Brick#hasPart hvac.eas.terHea
# hvac.eas.senTem a https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor
# hvac.eas https://brickschema.org/schema/Brick#hasPoint hvac.eas.senTem
# hvac.eas.senVolFlo a https://brickschema.org/schema/Brick#Supply_Air_Flow_Sensor
# hvac.eas https://brickschema.org/schema/Brick#hasPoint hvac.eas.senVolFlo
# hvac.eas.val a https://brickschema.org/schema/Brick#Heating_Valve
# hvac.eas https://brickschema.org/schema/Brick#hasPart hvac.eas.val
# hvac.eas.val https://brickschema.org/schema/Brick#feeds hvac.eas.terHea
# hvac.eas.yHea a https://brickschema.org/schema/Brick#Valve_Command
# hvac.eas https://brickschema.org/schema/Brick#hasPoint hvac.eas.yHea
# hvac.nor a https://brickschema.org/schema/Brick#VAV
# hvac https://brickschema.org/schema/Brick#hasPart hvac.nor
# hvac.nor.vav a https://brickschema.org/schema/Brick#Damper
# hvac.nor https://brickschema.org/schema/Brick#hasPart hvac.nor.vav
# hvac.nor.terHea a https://brickschema.org/schema/Brick#Heating_Coil
# hvac.nor https://brickschema.org/schema/Brick#hasPart hvac.nor.terHea
# hvac.nor.senTem a https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor
# hvac.nor https://brickschema.org/schema/Brick#hasPoint hvac.nor.senTem
# hvac.nor.senVolFlo a https://brickschema.org/schema/Brick#Supply_Air_Flow_Sensor
# hvac.nor https://brickschema.org/schema/Brick#hasPoint hvac.nor.senVolFlo
# hvac.nor.val a https://brickschema.org/schema/Brick#Heating_Valve
# hvac.nor https://brickschema.org/schema/Brick#hasPart hvac.nor.val
# hvac.nor.val https://brickschema.org/schema/Brick#feeds hvac.nor.terHea
# hvac.nor.yHea a https://brickschema.org/schema/Brick#Valve_Command
# hvac.nor https://brickschema.org/schema/Brick#hasPoint hvac.nor.yHea
# hvac.wes a https://brickschema.org/schema/Brick#VAV
# hvac https://brickschema.org/schema/Brick#hasPart hvac.wes
# hvac.wes.vav a https://brickschema.org/schema/Brick#Damper
# hvac.wes https://brickschema.org/schema/Brick#hasPart hvac.wes.vav
# hvac.wes.terHea a https://brickschema.org/schema/Brick#Heating_Coil
# hvac.wes https://brickschema.org/schema/Brick#hasPart hvac.wes.terHea
# hvac.wes.senTem a https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor
# hvac.wes https://brickschema.org/schema/Brick#hasPoint hvac.wes.senTem
# hvac.wes.senVolFlo a https://brickschema.org/schema/Brick#Supply_Air_Flow_Sensor
# hvac.wes https://brickschema.org/schema/Brick#hasPoint hvac.wes.senVolFlo
# hvac.wes.val a https://brickschema.org/schema/Brick#Heating_Valve
# hvac.wes https://brickschema.org/schema/Brick#hasPart hvac.wes.val
# hvac.wes.val https://brickschema.org/schema/Brick#feeds hvac.wes.terHea
# hvac.wes.yHea a https://brickschema.org/schema/Brick#Valve_Command
# hvac.wes https://brickschema.org/schema/Brick#hasPoint hvac.wes.yHea
# hvac.damExh a https://brickschema.org/schema/Brick#Exhaust_Damper
# hvac https://brickschema.org/schema/Brick#hasPart hvac.damExh
# hvac.reaAhu.TSup a https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor
# hvac.reaAhu.TMix a https://brickschema.org/schema/Brick#Mixed_Air_Temperature_Sensor
# hvac.reaAhu.TRet a https://brickschema.org/schema/Brick#Return_Air_Temperature_Sensor
# hvac.reaAhu.V_flow_sup a https://brickschema.org/schema/Brick#Supply_Air_Flow_Sensor
# hvac.reaAhu.V_flow_ret a https://brickschema.org/schema/Brick#Return_Air_Flow_Sensor
# hvac.reaAhu.dp_sup a https://brickschema.org/schema/Brick#Discharge_Air_Static_Pressure_Sensor
# hvac.reaAhu.PFanSup a https://brickschema.org/schema/Brick#Electrical_Power_Sensor
# hvac.reaAhu.PPumCoo a https://brickschema.org/schema/Brick#Electrical_Power_Sensor
# hvac.reaAhu.PPumHea a https://brickschema.org/schema/Brick#Electrical_Power_Sensor
# hvac.reaAhu.TCooCoiSup a https://brickschema.org/schema/Brick#Chilled_Water_Supply_Temperature_Sensor
# hvac.reaAhu.TCooCoiRet a https://brickschema.org/schema/Brick#Chilled_Water_Return_Temperature_Sensor
# hvac.reaAhu.THeaCoiSup a https://brickschema.org/schema/Brick#Hot_Water_Supply_Temperature_Sensor
# hvac.reaAhu.THeaCoiRet a https://brickschema.org/schema/Brick#Hot_Water_Return_Temperature_Sensor
# hvac.reaZonCor.TZon a https://brickschema.org/schema/Brick#Zone_Air_Temperature_Sensor
# hvac.reaZonCor.TSup a https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor
# hvac.reaZonCor.V_flow a https://brickschema.org/schema/Brick#Discharge_Air_Flow_Sensor
# hvac.reaZonCor.CO2Zon a https://brickschema.org/schema/Brick#CO2_Sensor
# hvac.reaZonSou a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.reaZonSou.TZon a https://brickschema.org/schema/Brick#Zone_Air_Temperature_Sensor
# hvac.reaZonSou https://brickschema.org/schema/Brick#hasPoint hvac.reaZonSou.TZon
# hvac.reaZonSou.TSup a https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor
# hvac.reaZonSou https://brickschema.org/schema/Brick#hasPoint hvac.reaZonSou.TSup
# hvac.reaZonSou.V_flow a https://brickschema.org/schema/Brick#Discharge_Air_Flow_Sensor
# hvac.reaZonSou https://brickschema.org/schema/Brick#hasPoint hvac.reaZonSou.V_flow
# hvac.reaZonSou.CO2Zon a https://brickschema.org/schema/Brick#CO2_Sensor
# hvac.reaZonSou https://brickschema.org/schema/Brick#hasPoint hvac.reaZonSou.CO2Zon
# hvac.reaZonEas a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.reaZonEas.TZon a https://brickschema.org/schema/Brick#Zone_Air_Temperature_Sensor
# hvac.reaZonEas https://brickschema.org/schema/Brick#hasPoint hvac.reaZonEas.TZon
# hvac.reaZonEas.TSup a https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor
# hvac.reaZonEas https://brickschema.org/schema/Brick#hasPoint hvac.reaZonEas.TSup
# hvac.reaZonEas.V_flow a https://brickschema.org/schema/Brick#Discharge_Air_Flow_Sensor
# hvac.reaZonEas https://brickschema.org/schema/Brick#hasPoint hvac.reaZonEas.V_flow
# hvac.reaZonEas.CO2Zon a https://brickschema.org/schema/Brick#CO2_Sensor
# hvac.reaZonEas https://brickschema.org/schema/Brick#hasPoint hvac.reaZonEas.CO2Zon
# hvac.reaZonNor a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.reaZonNor.TZon a https://brickschema.org/schema/Brick#Zone_Air_Temperature_Sensor
# hvac.reaZonNor https://brickschema.org/schema/Brick#hasPoint hvac.reaZonNor.TZon
# hvac.reaZonNor.TSup a https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor
# hvac.reaZonNor https://brickschema.org/schema/Brick#hasPoint hvac.reaZonNor.TSup
# hvac.reaZonNor.V_flow a https://brickschema.org/schema/Brick#Discharge_Air_Flow_Sensor
# hvac.reaZonNor https://brickschema.org/schema/Brick#hasPoint hvac.reaZonNor.V_flow
# hvac.reaZonNor.CO2Zon a https://brickschema.org/schema/Brick#CO2_Sensor
# hvac.reaZonNor https://brickschema.org/schema/Brick#hasPoint hvac.reaZonNor.CO2Zon
# hvac.reaZonWes a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.reaZonWes.TZon a https://brickschema.org/schema/Brick#Zone_Air_Temperature_Sensor
# hvac.reaZonWes https://brickschema.org/schema/Brick#hasPoint hvac.reaZonWes.TZon
# hvac.reaZonWes.TSup a https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor
# hvac.reaZonWes https://brickschema.org/schema/Brick#hasPoint hvac.reaZonWes.TSup
# hvac.reaZonWes.V_flow a https://brickschema.org/schema/Brick#Discharge_Air_Flow_Sensor
# hvac.reaZonWes https://brickschema.org/schema/Brick#hasPoint hvac.reaZonWes.V_flow
# hvac.reaZonWes.CO2Zon a https://brickschema.org/schema/Brick#CO2_Sensor
# hvac.reaZonWes https://brickschema.org/schema/Brick#hasPoint hvac.reaZonWes.CO2Zon
# hvac.oveZonActCor a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.oveZonActCor.yDam a https://brickschema.org/schema/Brick#Damper_Position_Setpoint
# hvac.oveZonActCor https://brickschema.org/schema/Brick#hasPoint hvac.oveZonActCor.yDam
# hvac.oveZonActCor.yReaHea a https://brickschema.org/schema/Brick#Valve_Command
# hvac.oveZonActCor https://brickschema.org/schema/Brick#hasPoint hvac.oveZonActCor.yReaHea
# hvac.oveZonActSou a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.oveZonActSou.yDam a https://brickschema.org/schema/Brick#Damper_Position_Setpoint
# hvac.oveZonActSou https://brickschema.org/schema/Brick#hasPoint hvac.oveZonActSou.yDam
# hvac.oveZonActSou.yReaHea a https://brickschema.org/schema/Brick#Valve_Command
# hvac.oveZonActSou https://brickschema.org/schema/Brick#hasPoint hvac.oveZonActSou.yReaHea
# hvac.oveZonActEas a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.oveZonActEas.yDam a https://brickschema.org/schema/Brick#Damper_Position_Setpoint
# hvac.oveZonActEas https://brickschema.org/schema/Brick#hasPoint hvac.oveZonActEas.yDam
# hvac.oveZonActEas.yReaHea a https://brickschema.org/schema/Brick#Valve_Command
# hvac.oveZonActEas https://brickschema.org/schema/Brick#hasPoint hvac.oveZonActEas.yReaHea
# hvac.oveZonActNor a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.oveZonActNor.yDam a https://brickschema.org/schema/Brick#Damper_Position_Setpoint
# hvac.oveZonActNor https://brickschema.org/schema/Brick#hasPoint hvac.oveZonActNor.yDam
# hvac.oveZonActNor.yReaHea a https://brickschema.org/schema/Brick#Valve_Command
# hvac.oveZonActNor https://brickschema.org/schema/Brick#hasPoint hvac.oveZonActNor.yReaHea
# hvac.oveZonActWes a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.oveZonActWes.yDam a https://brickschema.org/schema/Brick#Damper_Position_Setpoint
# hvac.oveZonActWes https://brickschema.org/schema/Brick#hasPoint hvac.oveZonActWes.yDam
# hvac.oveZonActWes.yReaHea a https://brickschema.org/schema/Brick#Valve_Command
# hvac.oveZonActWes https://brickschema.org/schema/Brick#hasPoint hvac.oveZonActWes.yReaHea
# hvac.oveZonSupCor a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.oveZonSupCor.TZonHeaSet a https://brickschema.org/schema/Brick#Zone_Air_Heating_Temperature_Setpoint
# hvac.oveZonSupCor https://brickschema.org/schema/Brick#hasPoint hvac.oveZonSupCor.TZonHeaSet
# hvac.oveZonSupCor.TZonCooSet a https://brickschema.org/schema/Brick#Zone_Air_Cooling_Temperature_Setpoint
# hvac.oveZonSupCor https://brickschema.org/schema/Brick#hasPoint hvac.oveZonSupCor.TZonCooSet
# hvac.oveZonSupSou a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.oveZonSupSou.TZonHeaSet a https://brickschema.org/schema/Brick#Zone_Air_Heating_Temperature_Setpoint
# hvac.oveZonSupSou https://brickschema.org/schema/Brick#hasPoint hvac.oveZonSupSou.TZonHeaSet
# hvac.oveZonSupSou.TZonCooSet a https://brickschema.org/schema/Brick#Zone_Air_Cooling_Temperature_Setpoint
# hvac.oveZonSupSou https://brickschema.org/schema/Brick#hasPoint hvac.oveZonSupSou.TZonCooSet
# hvac.oveZonSupEas a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.oveZonSupEas.TZonHeaSet a https://brickschema.org/schema/Brick#Zone_Air_Heating_Temperature_Setpoint
# hvac.oveZonSupEas https://brickschema.org/schema/Brick#hasPoint hvac.oveZonSupEas.TZonHeaSet
# hvac.oveZonSupEas.TZonCooSet a https://brickschema.org/schema/Brick#Zone_Air_Cooling_Temperature_Setpoint
# hvac.oveZonSupEas https://brickschema.org/schema/Brick#hasPoint hvac.oveZonSupEas.TZonCooSet
# hvac.oveZonSupNor a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.oveZonSupNor.TZonHeaSet a https://brickschema.org/schema/Brick#Zone_Air_Heating_Temperature_Setpoint
# hvac.oveZonSupNor https://brickschema.org/schema/Brick#hasPoint hvac.oveZonSupNor.TZonHeaSet
# hvac.oveZonSupNor.TZonCooSet a https://brickschema.org/schema/Brick#Zone_Air_Cooling_Temperature_Setpoint
# hvac.oveZonSupNor https://brickschema.org/schema/Brick#hasPoint hvac.oveZonSupNor.TZonCooSet
# hvac.oveZonSupWes a https://brickschema.org/schema/Brick#HVAC_Zone
# hvac.oveZonSupWes.TZonHeaSet a https://brickschema.org/schema/Brick#Zone_Air_Heating_Temperature_Setpoint
# hvac.oveZonSupWes https://brickschema.org/schema/Brick#hasPoint hvac.oveZonSupWes.TZonHeaSet
# hvac.oveZonSupWes.TZonCooSet a https://brickschema.org/schema/Brick#Zone_Air_Cooling_Temperature_Setpoint
# hvac.oveZonSupWes https://brickschema.org/schema/Brick#hasPoint hvac.oveZonSupWes.TZonCooSet
# hvac a https://brickschema.org/schema/Brick#HVAC_System
# flo a https://brickschema.org/schema/Brick#Floor

# %%
# brick_types = {}
# for element in a:
#     type_specifier = a[element].get('type_specifier')
#     brick_type = None
    
#     if type_specifier.startswith("Buildings.Fluid.Sensors"):
#         brick_type = modelica_brick_sensor_type_map.get(type_specifier.split('Buildings.Fluid.Sensors.')[1], None)

#     if type_specifier.startswith("Buildings.Fluid.HeatExchangers"):
#         brick_type = modelica_brick_heat_exchanger_type_map.get(type_specifier.split('Buildings.Fluid.HeatExchangers.')[1], None)
    
#     if type_specifier.startswith("Buildings.Fluid.Actuators"):
#         brick_type = modelica_brick_actuator_type_map.get(type_specifier.split('Buildings.Fluid.Actuators.')[1], None)
        
#     if type_specifier.startswith("Buildings.Fluid.Movers"):
#         brick_type = modelica_brick_mover_type_map.get(type_specifier.split('Buildings.Fluid.Movers.')[1], None)
        
#     if type_specifier.startswith("Buildings.ThermalZones"):
#         brick_type = modelica_brick_thermal_zone_type_map.get(type_specifier.split('Buildings.ThermalZones.')[1], None)
    
#     if type_specifier.startswith("Buildings.Media"):
#         brick_type = modelica_brick_medium_type_map.get(type_specifier.split('Buildings.Media.')[1], None)
    
#     if brick_type is not None:
#         brick_types[element] = brick_type
