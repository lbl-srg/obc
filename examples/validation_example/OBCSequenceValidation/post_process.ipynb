# %%
import os
import pandas as pd

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

from buildingspy.io.outputfile import Reader
from buildingspy.io.postprocess import Plotter

# %%
reader = Reader('HeatingCoilValve_ValidationWithB33Data_alc.mat', "dymola")
df = pd.DataFrame()
df["time"] = list(reader.values("heaValSta_F_alc.TSup")[0])
df["mea_tsup"] = list(reader.values("heaValSta_F_alc.TSup")[1])
df["mea_tout"] = list(reader.values("heaValSta_F_alc.TOut")[1])
df["tsup_set"] = list(reader.values("heaValSta_F_alc.TSupSet")[1])
df["go_input"] = list(reader.values("heaValSta_F_alc.uEnable")[1])
df["valve_trend"] = list(reader.values("percConvHeaValSig.y")[1])
df["cont_sig_modelica_alc"] = list(reader.values("heaValSta_F_alc.yHeaVal")[1])

# %%
# list of even numbers range 0 - df.shape[0]
even_index = range(0, df.shape[0], 2)
df_at_change = df.loc[even_index, :].reset_index(drop = True)

# %%
def alc_controller(mea_T, set_T, int_error_prev_timestep, kp, ki, go_input):

    prop = kp * (set_T - mea_T)
    int_adder_this_timestep = ki * (set_T - (mea_T))
    inte = int_error_prev_timestep + go_input * int_adder_this_timestep
    
    sig = min(1, prop + inte)
    sig = max(sig, 0)
    
    return sig, prop, inte

# %%
df_at_change["sig"] = .5
df_at_change["prop"] = .5
df_at_change["inte"] = 0

# %%
for i in range(1, df_at_change.shape[0]):
    mea_t = df_at_change.loc[i, "mea_tsup"]
    set_t = df_at_change.loc[i, "tsup_set"]
    go_input = df_at_change.loc[i, "go_input"]
    int_error_prev_timestep = df_at_change.loc[i - 1, "inte"]
    sig, prop, inte = alc_controller(mea_t, set_t, int_error_prev_timestep, .05, .005, go_input)

    df_at_change.loc[i, "sig"] = sig
    df_at_change.loc[i, "prop"] = prop
    df_at_change.loc[i, "inte"] = inte

# %%
df_test = df_at_change.loc[600:650, :]
df_test
# Out:
#           time   mea_tsup  mea_tout  tsup_set  go_input  valve_trend  \
# 600  7915322.0  66.099998   9.93889      66.0       1.0        0.454
# 601  7915337.0  66.099998   9.93889      66.0       1.0        0.454
# 602  7915352.0  66.099998   9.93889      66.0       1.0        0.454
# 603  7915367.0  66.099998   9.93889      66.0       1.0        0.454
# 604  7915382.0  66.099998   9.93889      66.0       1.0        0.454
# 605  7915397.0  66.099998   9.93889      66.0       1.0        0.454
# 606  7915412.0  66.099998   9.93889      66.0       1.0        0.454
# 607  7915427.0  66.099998   9.93889      66.0       1.0        0.454
# 608  7915442.0  66.099998   9.93889      66.0       1.0        0.454
# 609  7915457.0  66.099998   9.93889      66.0       1.0        0.454
# 610  7915472.0  66.099998   9.93889      66.0       1.0        0.454
# 611  7915487.0  66.099998   9.93889      66.0       1.0        0.454
# 612  7915502.0  65.800003   9.93889      66.0       1.0        0.492
# ...

# %%
df_test.round(3).to_csv('test.csv')

# %%
round(66.5)
# Out:
# 67.0
